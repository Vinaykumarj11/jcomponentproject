# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Concrete_Data.csv')
df.head()
# Out:
#    Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse_Aggregate  Fine_Aggregate  Age  Concrete_compressive_strength
# 0            1040.0           676.0   28                          79.99
# 1            1055.0           676.0   28                          61.89
# 2             932.0           594.0  270                          40.27
# 3             932.0           594.0  365                          41.05
# 4             978.4           825.5  360                          44.30

# %%
# Checking for the shape
df.shape
# Out:
# (1030, 9)

# %%
# Checking for the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1030 non-null   float64
#  1   Blast_Furnace_Slag             1030 non-null   float64
#  2   Fly_Ash                        1030 non-null   float64
#  3   Water                          1030 non-null   float64
#  4   Superplasticizer               1030 non-null   float64
#  5   Coarse_Aggregate               1030 non-null   float64
#  6   Fine_Aggregate                 1030 non-null   float64
#  7   Age                            1030 non-null   int64
#  8   Concrete_compressive_strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
# Checking if any data is missing
df.isna().any()
# Out:
# Cement                           False
# Blast_Furnace_Slag               False
# Fly_Ash                          False
# Water                            False
# Superplasticizer                 False
# Coarse_Aggregate                 False
# Fine_Aggregate                   False
# Age                              False
# Concrete_compressive_strength    False
# dtype: bool

# %%
sns.displot(df['Cement'],kde=True)
plt.title("Distribution Plot for Cement")
plt.show()

# %%
sns.displot(df['Blast_Furnace_Slag'],kde=True)
plt.title("Distribution Plot for Slag")
plt.show()

# %%
sns.displot(df['Fly_Ash'],kde=True)
plt.title("Distribution Plot for Fly ash")
plt.show()

# %%
sns.displot(df['Water'],kde=True)
plt.title("Distribution Plot for Water")
plt.show()

# %%
sns.displot(df['Superplasticizer'],kde=True)
plt.title("Distribution Plot for SP")
plt.show()

# %%
sns.displot(df['Coarse_Aggregate'],kde=True)
plt.title("Distribution Plot for Coarse Aggr.")
plt.show()

# %%
sns.displot(df['Fine_Aggregate'],kde=True)
plt.title("Distribution Plot for Fine Aggr.")
plt.show()

# %%
sns.displot(df['Age'],kde=True)
plt.title("Distribution Plot for age")
plt.show()

# %%
# Checking for the pairplot
sns.pairplot(df)
plt.show()

# %%
# Checking for the correlations
df.corr()
# Out:
#                                  Cement  Blast_Furnace_Slag   Fly_Ash  \
# Cement                         1.000000           -0.275216 -0.397467
# Blast_Furnace_Slag            -0.275216            1.000000 -0.323580
# Fly_Ash                       -0.397467           -0.323580  1.000000
# Water                         -0.081587            0.107252 -0.256984
# Superplasticizer               0.092386            0.043270  0.377503
# Coarse_Aggregate              -0.109349           -0.283999 -0.009961
# Fine_Aggregate                -0.222718           -0.281603  0.079108
# Age                            0.081946           -0.044246 -0.154371
# Concrete_compressive_strength  0.497832            0.134829 -0.105755
#
#                                   Water  Superplasticizer  Coarse_Aggregate  \
# Cement                        -0.081587          0.092386         -0.109349
# Blast_Furnace_Slag             0.107252          0.043270         -0.283999
# ...

# %%
# Plotting the heatmap for the correlated data
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='viridis')
plt.show()

# %%
# Since the target variable is known, we can also get the correlations directly with the target variable
df.corr()['Concrete_compressive_strength']
# Out:
# Cement                           0.497832
# Blast_Furnace_Slag               0.134829
# Fly_Ash                         -0.105755
# Water                           -0.289633
# Superplasticizer                 0.366079
# Coarse_Aggregate                -0.164935
# Fine_Aggregate                  -0.167241
# Age                              0.328873
# Concrete_compressive_strength    1.000000
# Name: Concrete_compressive_strength, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df.columns
# Out:
# Index(['Cement', 'Blast_Furnace_Slag', 'Fly_Ash', 'Water', 'Superplasticizer',
#        'Coarse_Aggregate', 'Fine_Aggregate', 'Age',
#        'Concrete_compressive_strength'],
#       dtype='object')

# %%
# Defining X and y
X = df.drop('Concrete_compressive_strength', axis=1)
y = df['Concrete_compressive_strength']

# %%
# Splitting into training (70%) and testing (30%) datasets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=101)

# %%
# Standardizing dataset with Standard Scaler and Scaling is a MUST for Support Vector Machine modeling
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
base_model = SVR()

# %%
# Fitting scaled X_train and y_train and then predict with base model
base_model.fit(scaled_X_train,y_train)
base_pred = base_model.predict(scaled_X_test)

# %%
print("Mean Absolute Error is:",mean_absolute_error(y_test,base_pred))
# Out:
# Mean Absolute Error is: 8.416154485083204

# %%
print("Mean Squared Error is:",np.sqrt(mean_squared_error(y_test,base_pred)))
# Out:
# Mean Squared Error is: 10.78176802259589

# %%
print("Mean value of the y_test is:", y_test.mean())
# Out:
# Mean value of the y_test is: 36.39168284789643

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'kernel': ['linear', 'rbf', 'poly'],
             'degree':[2,3,4],
             'gamma': ['scale','auto'],
             'C': [0.001,0.01,0.1,0.5,1],
             'epsilon': [0,0.001,0.01,0.1,0.5,1,2]}

# %%
# Performing cross validation on the training dataset
svr = SVR()
grid = GridSearchCV(svr, param_grid)

# %%
# Fitting scaled training data set
grid.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1], 'degree': [2, 3, 4],
#                          'epsilon': [0, 0.001, 0.01, 0.1, 0.5, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
# Finding the best parameters
grid.best_params_
# Out:
# {'C': 0.5, 'degree': 2, 'epsilon': 1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
# Finding predicted values based on the above best paramters selected by the Grid Search
grid_pred = grid.predict(scaled_X_test)

# %%
# Finding mean absolute error for the grid model
print("Mean Absolute Error for Grid Model is:",mean_absolute_error(y_test,grid_pred))
# Out:
# Mean Absolute Error for Grid Model is: 8.706061084095639

# %%
# Finding mean squared error for the grid model
print("Mean Squared Error for Grid Model is:",np.sqrt(mean_squared_error(y_test,grid_pred)))
# Out:
# Mean Squared Error for Grid Model is: 11.376956473796447

# %%
# Finding mean absolute error for the base model
print("Mean Absolute Error for Base Model is:",mean_absolute_error(y_test,base_pred))
# Out:
# Mean Absolute Error for Base Model is: 8.416154485083204

# %%
# Finding mean squared error for the base model
print("Mean Squared Error for Base Model is:",np.sqrt(mean_squared_error(y_test,base_pred)))
# Out:
# Mean Squared Error for Base Model is: 10.78176802259589

# %%
# Finding mean absolute error for the grid model
print("Mean Absolute Error for Grid Optimized Model is:",mean_absolute_error(y_test,grid_pred))
# Out:
# Mean Absolute Error for Grid Optimized Model is: 8.706061084095639

# %%
# Finding mean squared error for the grid model
print("Mean Squared Error for Grid Optimized Model is:",np.sqrt(mean_squared_error(y_test,grid_pred)))
# Out:
# Mean Squared Error for Grid Optimized Model is: 11.376956473796447
